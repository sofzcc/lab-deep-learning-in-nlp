# %% [markdown]
# # Deep Learning in NLP

# %% [markdown]
# <center><img src="https://education-team-2020.s3.eu-west-1.amazonaws.com/ai-eng/w4-s3/deep_learning.png" width="1000"/></center>

# %% [markdown]
# ----
# Apply word2vec to a dataset
# -----
#
# Overview:
#
# 1. Download some training data
# 1. Setup word2vec model in TensorFlow
# 1. Train on the data
# 1. Visualize the result

# %%
reset -fs

# %%
# I like to live dangerously ☠
import warnings
warnings.filterwarnings('ignore')

# %%
import collections
import math
import os
from pprint import pprint
import random
import urllib.request
import zipfile

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf 
from sklearn.manifold import TSNE

# %matplotlib inline
# Out:
# 2024-06-12 15:37:44.730426: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ----
# Step 1: Download the data.
# ----

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(path, filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    
    if not os.path.exists(path+filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    
    statinfo = os.stat(path+filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    
    return filename

path = ""
filename = maybe_download(path, 'text8.zip', 31_344_016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# While this code ☝️  is running ⏳, preview the code ahead 🔍.

# %%
# Read the data into a list of strings.
def read_data(path, filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(path+filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_data(path, filename)
print('Dataset size: {:,} words'.format(len(vocabulary)))
# Out:
# Dataset size: 17,005,207 words

# %%
# Take a peak at the head
vocabulary[:20]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english']

# %% [markdown]
# Notice: None of the words are capitalized and there is no punctuation.
#
# Preprocessing is an art. It depends on your raw data and how you plan to use your final data. You might want to encode ngrams, instead of just splitting all items into unigrams.

# %% [markdown]
# -----
# Step 2: Build the dictionary
# -----

# %%
vocabulary_size = 50_000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)

# %% [markdown]
# Variable Legend
# ------
# data - list of codes (integers from 0 to vocabulary_size-1).
#     This is the original text but words are replaced by their codes
#
# count - map of words(strings) to count of occurrences
#
# dictionary - map of words(strings) to their codes(integers)
#
# reverse_dictionary - maps codes(integers) to words(strings)

# %%
del vocabulary # Reduce memory by getting rid of the "heavy" list of strings

# %%
data[:5] # An index of each word (as it appears in order) to its rank. Therefore we don't have reference the string
# Out:
# [5234, 3081, 12, 6, 195]

# %%
dictionary['the'] # word: rank
# Out:
# 1

# %%
reverse_dictionary[5234] # rank: word
# Out:
# 'anarchism'

# %%
print('Most common words:') 
print(*count[:5], sep="\n")
# Out:
# Most common words:
# ['UNK', 418391]
# ('the', 1061396)
# ('of', 593677)
# ('and', 416629)
# ('one', 411764)

# %%
print('Most least words:')
print(*count[-5:], sep="\n")
# Out:
# Most least words:
# ('codeword', 9)
# ('senussi', 9)
# ('unscr', 9)
# ('leonards', 9)
# ('hif', 9)

# %% [markdown]
# ----
# Step 3: Function to generate a training batch for the skip-gram model.
# -----

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer[:] = data[:span]
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, 
                               num_skips=2, 
                               skip_window=1)

# %%
# Example of self-supervised learning
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of

# %% [markdown]
# ----
# Step 4: Build and train a skip-gram model.
# -----

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
import tensorflow.compat.v1 as v1

# %%
graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = v1.placeholder(tf.int32, shape=[batch_size])
    train_labels = v1.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = v1.constant(valid_examples, dtype=tf.int32)

    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            v1.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            v1.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

        # Compute the average NCE loss for the batch.
        # tf.nce_loss automatically draws a new sample of the negative labels each
        # time we evaluate the loss.
        # Explanation of the meaning of NCE loss:
        #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
        loss = tf.reduce_mean(
          tf.nn.nce_loss(weights=nce_weights,
                         biases=nce_biases,
                         labels=train_labels,
                         inputs=embed,
                         num_sampled=num_sampled,
                         num_classes=vocabulary_size))

        # Construct the SGD optimizer using a learning rate of 1.0.
        optimizer = v1.train.GradientDescentOptimizer(1.0).minimize(loss)

        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(
          normalized_embeddings, valid_dataset)
        similarity = tf.matmul(
          valid_embeddings, normalized_embeddings, transpose_b=True)

        # Add variable initializer.
        init = v1.global_variables_initializer()

# %% [markdown]
# ----
# Step 5: Begin training.
# -----

# %%
num_steps = 100_001 #1 #2_001 #100_001

with v1.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2_000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 2_000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 4 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to '%s':" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
            print()
    final_embeddings = normalized_embeddings.eval()
# Out:
# 2024-06-12 15:40:50.405087: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# Initialized
# Average loss at step  0 :  292.9666442871094
# Nearest to 'people': cryogenic, twas, dactyl, xxvii,
# Nearest to 'and': milgrom, anzus, gigue, lead,
# Nearest to 'it': sensing, shield, abyssinia, centrist,
# Nearest to 'there': albany, repressive, siwa, bags,
# Nearest to 'eight': jennifer, hain, ennio, settler,
# Nearest to 'or': defendants, warmest, porridge, scrat,
# Nearest to 'other': varanus, calatrava, stahl, screenshot,
# Nearest to 'be': saccharomyces, harshness, curie, comparisons,
# Nearest to 'years': lehmann, dubh, sprang, boldly,
# Nearest to 'up': sinuous, decorate, bela, uninterested,
# Nearest to 'these': cub, adele, loyalist, furthering,
# Nearest to 'has': asheville, wound, slater, wan,
# Nearest to 'its': atheroma, leg, drum, zech,
# Nearest to 'five': apostate, mingled, schottky, housman,
# Nearest to 'united': hammer, troops, rupee, atacama,
# Nearest to 'between': homeopathic, dina, lauter, mycenean,
#
# Average loss at step  2000 :  114.07853604888916
# Nearest to 'people': vs, alien, use, jpg,
# Nearest to 'and': the, of, one, in,
# Nearest to 'it': technology, river, whether, the,
# Nearest to 'there': wimbledon, eventually, repressive, ayn,
# Nearest to 'eight': vs, samoa, good, subjects,
# Nearest to 'or': alien, six, x, management,
# Nearest to 'other': state, c, fauna, father,
# Nearest to 'be': legislation, result, vs, split,
# Nearest to 'years': baker, images, built, actively,
# Nearest to 'up': include, austin, understand, b,
# Nearest to 'these': ism, community, mention, isbn,
# Nearest to 'has': david, vs, wound, apollo,
# Nearest to 'its': awards, putative, teachers, started,
# Nearest to 'five': frames, chance, song, television,
# Nearest to 'united': frames, troops, think, rockets,
# Nearest to 'between': traditional, former, animals, north,
#
# Average loss at step  4000 :  52.36273487305641
# Nearest to 'people': vs, alien, use, contrast,
# Nearest to 'and': of, in, to, UNK,
# Nearest to 'it': technology, river, edmonton, agave,
# Nearest to 'there': agave, repressive, wimbledon, california,
# Nearest to 'eight': m, vs, samoa, agave,
# Nearest to 'or': alien, ambiguous, six, com,
# Nearest to 'other': state, c, var, hebrew,
# Nearest to 'be': result, legislation, saskatchewan, comparisons,
# Nearest to 'years': images, baker, creek, spangled,
# Nearest to 'up': include, austin, understand, short,
# Nearest to 'these': aldous, mention, ism, isbn,
# Nearest to 'has': tissue, david, was, vs,
# Nearest to 'its': awards, leg, teachers, thence,
# Nearest to 'five': var, pleas, chance, agave,
# Nearest to 'united': agave, troops, hammer, var,
# Nearest to 'between': traditional, former, animals, north,
#
# Average loss at step  6000 :  33.45029780220985
# Nearest to 'people': vs, alien, use, anesthesia,
# Nearest to 'and': in, of, UNK, mya,
# Nearest to 'it': technology, river, shield, edmonton,
# Nearest to 'there': albany, siwa, agave, california,
# Nearest to 'eight': agave, hakama, nine, vs,
# Nearest to 'or': alien, six, and, scenic,
# Nearest to 'other': state, sketching, c, hebrew,
# Nearest to 'be': result, legislation, split, saskatchewan,
# Nearest to 'years': built, impede, images, fort,
# Nearest to 'up': austin, include, understand, short,
# Nearest to 'these': mention, loyalist, aldous, ism,
# Nearest to 'has': was, tissue, vs, evangelical,
# Nearest to 'its': drum, leg, awards, cervical,
# Nearest to 'five': zero, six, chance, var,
# Nearest to 'united': agave, troops, hammer, var,
# Nearest to 'between': former, traditional, howe, animals,
#
# Average loss at step  8000 :  23.293866719961166
# Nearest to 'people': vs, use, anesthesia, contrast,
# Nearest to 'and': of, in, UNK, archie,
# Nearest to 'it': phi, he, technology, UNK,
# Nearest to 'there': albany, siwa, alvin, agave,
# Nearest to 'eight': nine, UNK, three, agave,
# Nearest to 'or': gb, and, six, alien,
# Nearest to 'other': state, hebrew, sketching, c,
# Nearest to 'be': sanjaks, result, legislation, aberdeenshire,
# Nearest to 'years': eurovision, built, coke, images,
# Nearest to 'up': austin, include, understand, short,
# Nearest to 'these': mention, ism, loyalist, aldous,
# Nearest to 'has': was, sandwich, is, tissue,
# Nearest to 'its': the, drum, coke, leg,
# Nearest to 'five': zero, UNK, six, nine,
# Nearest to 'united': agave, troops, think, hammer,
# Nearest to 'between': former, traditional, north, howe,
#
# Average loss at step  10000 :  17.847696105480193
# Nearest to 'people': anesthesia, vs, use, contrast,
# Nearest to 'and': in, of, coke, s,
# Nearest to 'it': he, phi, technology, river,
# Nearest to 'there': albany, siwa, szlachta, repressive,
# Nearest to 'eight': nine, zero, three, one,
# Nearest to 'or': gb, and, six, quit,
# Nearest to 'other': state, hebrew, levi, sketching,
# Nearest to 'be': sanjaks, result, legislation, aberdeenshire,
# Nearest to 'years': eurovision, three, images, guests,
# Nearest to 'up': austin, include, understand, short,
# Nearest to 'these': mention, two, ism, ping,
# Nearest to 'has': was, is, sandwich, are,
# Nearest to 'its': the, drum, coke, leg,
# Nearest to 'five': nine, zero, eight, six,
# Nearest to 'united': agave, troops, think, hammer,
# Nearest to 'between': former, traditional, howe, north,
#
# Average loss at step  12000 :  14.253172120690346
# Nearest to 'people': xxvii, vs, anesthesia, use,
# Nearest to 'and': in, one, of, s,
# Nearest to 'it': he, phi, and, river,
# Nearest to 'there': albany, siwa, alvin, sayings,
# Nearest to 'eight': nine, zero, three, five,
# Nearest to 'or': and, gb, six, UNK,
# Nearest to 'other': state, hebrew, levi, sketching,
# Nearest to 'be': was, sanjaks, result, have,
# Nearest to 'years': eurovision, three, sprang, images,
# Nearest to 'up': austin, include, one, understand,
# Nearest to 'these': two, mention, ism, ping,
# Nearest to 'has': was, is, sandwich, in,
# Nearest to 'its': the, drum, coke, awards,
# Nearest to 'five': nine, eight, zero, six,
# Nearest to 'united': agave, troops, think, var,
# Nearest to 'between': former, north, traditional, enlist,
#
# Average loss at step  14000 :  11.66838937330246
# Nearest to 'people': xxvii, anesthesia, vs, options,
# Nearest to 'and': in, agouti, circ, of,
# Nearest to 'it': he, and, dasyprocta, phi,
# Nearest to 'there': albany, sayings, alvin, siwa,
# Nearest to 'eight': nine, circ, dasyprocta, agouti,
# Nearest to 'or': and, gb, six, dasyprocta,
# Nearest to 'other': state, hebrew, levi, sketching,
# Nearest to 'be': was, have, is, sanjaks,
# Nearest to 'years': dasyprocta, eurovision, three, sprang,
# Nearest to 'up': dasyprocta, operatorname, austin, decorate,
# Nearest to 'these': two, ism, mention, compilers,
# Nearest to 'has': is, was, sandwich, circ,
# Nearest to 'its': the, drum, coke, dasyprocta,
# Nearest to 'five': nine, circ, zero, eight,
# Nearest to 'united': agouti, agave, troops, monastic,
# Nearest to 'between': imperator, former, traditional, north,
#
# Average loss at step  16000 :  9.90346289384365
# Nearest to 'people': xxvii, anesthesia, vs, circ,
# Nearest to 'and': in, agouti, circ, one,
# Nearest to 'it': he, they, ulyanov, circ,
# Nearest to 'there': albany, latinus, sayings, agatha,
# Nearest to 'eight': nine, zero, circ, three,
# Nearest to 'or': and, six, gb, dasyprocta,
# Nearest to 'other': state, hebrew, levi, sketching,
# Nearest to 'be': was, have, is, sanjaks,
# Nearest to 'years': dasyprocta, eurovision, three, sprang,
# Nearest to 'up': dasyprocta, decorate, operatorname, austin,
# Nearest to 'these': two, compilers, ism, mention,
# Nearest to 'has': is, was, sandwich, had,
# Nearest to 'its': the, drum, coke, dasyprocta,
# Nearest to 'five': nine, zero, eight, six,
# Nearest to 'united': troops, agouti, agave, monastic,
# Nearest to 'between': imperator, traditional, north, former,
#
# Average loss at step  18000 :  8.43285112208128
# Nearest to 'people': xxvii, vs, anesthesia, circ,
# Nearest to 'and': one, agouti, in, circ,
# Nearest to 'it': he, they, ulyanov, dasyprocta,
# Nearest to 'there': albany, latinus, sayings, siwa,
# Nearest to 'eight': nine, zero, six, five,
# Nearest to 'or': and, six, gb, dasyprocta,
# Nearest to 'other': state, hebrew, levi, sketching,
# Nearest to 'be': have, was, is, sanjaks,
# Nearest to 'years': dasyprocta, eurovision, three, sprang,
# Nearest to 'up': dasyprocta, decorate, operatorname, austin,
# Nearest to 'these': two, compilers, ism, mention,
# Nearest to 'has': was, is, had, sandwich,
# Nearest to 'its': the, their, drum, his,
# Nearest to 'five': eight, nine, zero, six,
# Nearest to 'united': agouti, agave, troops, monastic,
# Nearest to 'between': imperator, as, traditional, former,
#
# Average loss at step  20000 :  7.897343292474747
# Nearest to 'people': xxvii, anesthesia, vs, circ,
# Nearest to 'and': agouti, or, in, dasyprocta,
# Nearest to 'it': he, they, this, ulyanov,
# Nearest to 'there': albany, latinus, it, which,
# Nearest to 'eight': nine, six, five, zero,
# Nearest to 'or': and, six, gb, circ,
# Nearest to 'other': state, levi, shirkuh, hebrew,
# Nearest to 'be': have, was, is, sanjaks,
# Nearest to 'years': dasyprocta, three, eurovision, sprang,
# Nearest to 'up': dasyprocta, decorate, operatorname, austin,
# Nearest to 'these': compilers, two, ism, ping,
# Nearest to 'has': was, is, had, sandwich,
# Nearest to 'its': the, their, his, drum,
# Nearest to 'five': eight, nine, zero, six,
# Nearest to 'united': agouti, troops, agave, monastic,
# Nearest to 'between': in, as, imperator, traditional,
#
# Average loss at step  22000 :  7.066562893390656
# Nearest to 'people': xxvii, anesthesia, vs, dasyprocta,
# Nearest to 'and': or, one, agouti, in,
# Nearest to 'it': he, this, abet, they,
# Nearest to 'there': albany, it, latinus, koreans,
# Nearest to 'eight': nine, five, zero, six,
# Nearest to 'or': and, gb, six, dasyprocta,
# Nearest to 'other': state, levi, shirkuh, hebrew,
# Nearest to 'be': was, have, is, sanjaks,
# Nearest to 'years': dasyprocta, eurovision, three, sprang,
# Nearest to 'up': dasyprocta, decorate, abet, storms,
# Nearest to 'these': two, abet, compilers, ism,
# Nearest to 'has': was, is, had, sandwich,
# Nearest to 'its': the, their, his, drum,
# Nearest to 'five': eight, zero, nine, six,
# Nearest to 'united': troops, agouti, agave, monastic,
# Nearest to 'between': in, from, imperator, traditional,
#
# Average loss at step  24000 :  6.894565149426461
# Nearest to 'people': anesthesia, xxvii, dasyprocta, vs,
# Nearest to 'and': or, in, agouti, circ,
# Nearest to 'it': he, this, they, abet,
# Nearest to 'there': albany, it, latinus, which,
# Nearest to 'eight': nine, six, five, zero,
# Nearest to 'or': and, six, gb, circ,
# Nearest to 'other': state, shirkuh, levi, dasyprocta,
# Nearest to 'be': was, have, is, sanjaks,
# Nearest to 'years': dasyprocta, eurovision, three, sprang,
# Nearest to 'up': dasyprocta, decorate, abet, storms,
# Nearest to 'these': two, abet, compilers, the,
# Nearest to 'has': was, is, had, sandwich,
# Nearest to 'its': the, their, his, drum,
# Nearest to 'five': eight, six, nine, zero,
# Nearest to 'united': troops, agouti, agave, monastic,
# Nearest to 'between': in, imperator, from, as,
#
# Average loss at step  26000 :  6.771988748669624
# Nearest to 'people': xxvii, anesthesia, dasyprocta, mbit,
# Nearest to 'and': or, agouti, in, circ,
# Nearest to 'it': he, this, they, abet,
# Nearest to 'there': albany, it, latinus, koreans,
# Nearest to 'eight': nine, six, five, seven,
# Nearest to 'or': and, six, gb, dasyprocta,
# Nearest to 'other': state, hebrew, shirkuh, levi,
# Nearest to 'be': was, have, is, sanjaks,
# Nearest to 'years': dasyprocta, eurovision, three, five,
# Nearest to 'up': dasyprocta, decorate, abet, storms,
# Nearest to 'these': two, abet, compilers, the,
# Nearest to 'has': was, is, had, sandwich,
# Nearest to 'its': the, their, his, drum,
# Nearest to 'five': eight, six, nine, seven,
# Nearest to 'united': troops, agouti, agave, taos,
# Nearest to 'between': imperator, from, traditional, north,
#
# Average loss at step  28000 :  6.353806601285934
# Nearest to 'people': xxvii, amalthea, anesthesia, mbit,
# Nearest to 'and': or, agouti, in, one,
# Nearest to 'it': he, this, which, there,
# Nearest to 'there': it, albany, koreans, which,
# Nearest to 'eight': nine, six, five, seven,
# Nearest to 'or': and, gb, six, circ,
# Nearest to 'other': state, hebrew, shirkuh, levi,
# Nearest to 'be': have, was, been, sanjaks,
# Nearest to 'years': dasyprocta, eurovision, sprang, five,
# Nearest to 'up': dasyprocta, decorate, amalthea, abet,
# Nearest to 'these': two, compilers, abet, the,
# Nearest to 'has': was, is, had, amalthea,
# Nearest to 'its': the, their, his, abakan,
# Nearest to 'five': eight, six, seven, nine,
# Nearest to 'united': troops, agouti, agave, taos,
# Nearest to 'between': from, imperator, in, traditional,
#
# Average loss at step  30000 :  5.840726470947265
# Nearest to 'people': xxvii, amalthea, anesthesia, mbit,
# Nearest to 'and': or, agouti, dasyprocta, circ,
# Nearest to 'it': he, which, this, there,
# Nearest to 'there': it, albany, which, koreans,
# Nearest to 'eight': nine, six, five, seven,
# Nearest to 'or': and, circ, gb, dasyprocta,
# Nearest to 'other': shirkuh, different, state, hebrew,
# Nearest to 'be': have, was, is, been,
# Nearest to 'years': dasyprocta, eurovision, three, five,
# Nearest to 'up': dasyprocta, decorate, amalthea, storms,
# Nearest to 'these': two, cordoba, compilers, abet,
# Nearest to 'has': was, is, had, amalthea,
# Nearest to 'its': the, their, his, abakan,
# Nearest to 'five': eight, six, seven, four,
# Nearest to 'united': troops, agouti, agave, taos,
# Nearest to 'between': from, traditional, imperator, former,
#
# Average loss at step  32000 :  5.997374258637429
# Nearest to 'people': amalthea, xxvii, anesthesia, mbit,
# Nearest to 'and': or, agouti, in, circ,
# Nearest to 'it': he, this, which, there,
# Nearest to 'there': it, albany, which, koreans,
# Nearest to 'eight': nine, six, five, seven,
# Nearest to 'or': and, circ, gb, six,
# Nearest to 'other': different, shirkuh, hebrew, income,
# Nearest to 'be': have, was, been, is,
# Nearest to 'years': dasyprocta, eurovision, three, sprang,
# Nearest to 'up': dasyprocta, decorate, amalthea, storms,
# Nearest to 'these': cordoba, many, two, compilers,
# Nearest to 'has': was, is, had, amalthea,
# Nearest to 'its': the, their, his, abakan,
# Nearest to 'five': eight, six, seven, four,
# Nearest to 'united': agouti, agave, troops, atacama,
# Nearest to 'between': from, traditional, in, imperator,
#
# Average loss at step  34000 :  5.771611276149749
# Nearest to 'people': amalthea, anesthesia, xxvii, vma,
# Nearest to 'and': or, agouti, in, dasyprocta,
# Nearest to 'it': he, which, this, they,
# Nearest to 'there': it, which, albany, koreans,
# Nearest to 'eight': nine, six, seven, five,
# Nearest to 'or': and, circ, gb, dasyprocta,
# Nearest to 'other': different, shirkuh, several, hebrew,
# Nearest to 'be': have, was, been, sanjaks,
# Nearest to 'years': dasyprocta, eurovision, three, five,
# Nearest to 'up': dasyprocta, decorate, amalthea, abet,
# Nearest to 'these': two, cordoba, many, ping,
# Nearest to 'has': was, is, had, amalthea,
# Nearest to 'its': the, their, his, abakan,
# Nearest to 'five': three, seven, four, six,
# Nearest to 'united': agouti, agave, troops, atacama,
# Nearest to 'between': from, in, traditional, former,
#
# Average loss at step  36000 :  5.789398267149926
# Nearest to 'people': amalthea, anesthesia, xxvii, vma,
# Nearest to 'and': or, in, agouti, dasyprocta,
# Nearest to 'it': he, this, which, there,
# Nearest to 'there': it, which, albany, koreans,
# Nearest to 'eight': nine, six, seven, five,
# Nearest to 'or': and, circ, gb, dasyprocta,
# Nearest to 'other': different, shirkuh, several, dasyprocta,
# Nearest to 'be': have, was, been, is,
# Nearest to 'years': dasyprocta, eurovision, five, three,
# Nearest to 'up': decorate, dasyprocta, storms, amalthea,
# Nearest to 'these': many, cordoba, two, ping,
# Nearest to 'has': was, is, had, amalthea,
# Nearest to 'its': the, their, his, abakan,
# Nearest to 'five': four, seven, six, three,
# Nearest to 'united': agouti, agave, troops, atacama,
# Nearest to 'between': from, in, traditional, former,
#
# Average loss at step  38000 :  5.531753556728363
# Nearest to 'people': xxvii, anesthesia, amalthea, plantation,
# Nearest to 'and': or, in, agouti, dasyprocta,
# Nearest to 'it': he, this, there, which,
# Nearest to 'there': it, which, albany, he,
# Nearest to 'eight': six, nine, seven, five,
# Nearest to 'or': and, circ, gb, dasyprocta,
# Nearest to 'other': different, three, shirkuh, several,
# Nearest to 'be': have, was, been, sanjaks,
# Nearest to 'years': dasyprocta, five, eurovision, three,
# Nearest to 'up': decorate, dasyprocta, storms, amalthea,
# Nearest to 'these': many, cordoba, two, ping,
# Nearest to 'has': was, is, had, amalthea,
# Nearest to 'its': their, the, his, abakan,
# Nearest to 'five': four, three, six, eight,
# Nearest to 'united': agouti, agave, troops, atacama,
# Nearest to 'between': from, in, traditional, former,
#
# Average loss at step  40000 :  5.2732750889062885
# Nearest to 'people': xxvii, zero, anesthesia, plantation,
# Nearest to 'and': or, zero, agouti, dasyprocta,
# Nearest to 'it': he, this, which, there,
# Nearest to 'there': it, which, albany, he,
# Nearest to 'eight': six, seven, nine, zero,
# Nearest to 'or': and, zero, circ, dasyprocta,
# Nearest to 'other': different, three, shirkuh, several,
# Nearest to 'be': have, was, been, is,
# Nearest to 'years': dasyprocta, eurovision, five, six,
# Nearest to 'up': decorate, dasyprocta, storms, amalthea,
# Nearest to 'these': many, cordoba, two, all,
# Nearest to 'has': was, is, had, have,
# Nearest to 'its': their, the, his, abakan,
# Nearest to 'five': four, six, three, eight,
# Nearest to 'united': agouti, agave, troops, accounting,
# Nearest to 'between': from, in, former, traditional,
#
# Average loss at step  42000 :  5.355655132055283
# Nearest to 'people': amalthea, anesthesia, xxvii, vma,
# Nearest to 'and': or, agouti, but, circ,
# Nearest to 'it': he, this, there, they,
# Nearest to 'there': it, which, he, albany,
# Nearest to 'eight': six, nine, seven, five,
# Nearest to 'or': and, circ, dasyprocta, six,
# Nearest to 'other': different, three, shirkuh, several,
# Nearest to 'be': have, was, been, by,
# Nearest to 'years': dasyprocta, eurovision, five, six,
# Nearest to 'up': decorate, dasyprocta, amalthea, storms,
# Nearest to 'these': many, two, cordoba, all,
# Nearest to 'has': was, had, is, have,
# Nearest to 'its': their, the, his, abakan,
# Nearest to 'five': six, seven, four, three,
# Nearest to 'united': agouti, agave, troops, accounting,
# Nearest to 'between': from, in, traditional, former,
#
# Average loss at step  44000 :  5.242632161378861
# Nearest to 'people': amalthea, xxvii, plantation, anesthesia,
# Nearest to 'and': or, agouti, circ, dasyprocta,
# Nearest to 'it': he, this, there, which,
# Nearest to 'there': it, which, albany, koreans,
# Nearest to 'eight': nine, six, seven, five,
# Nearest to 'or': and, circ, dasyprocta, six,
# Nearest to 'other': different, three, several, shirkuh,
# Nearest to 'be': have, was, been, by,
# Nearest to 'years': dasyprocta, eurovision, six, three,
# Nearest to 'up': decorate, dasyprocta, amalthea, storms,
# Nearest to 'these': many, cordoba, all, two,
# Nearest to 'has': was, had, is, have,
# Nearest to 'its': their, the, his, abakan,
# Nearest to 'five': four, six, three, seven,
# Nearest to 'united': agouti, agave, troops, accounting,
# Nearest to 'between': from, in, traditional, former,
#
# Average loss at step  46000 :  5.222901421546936
# Nearest to 'people': xxvii, plantation, amalthea, anesthesia,
# Nearest to 'and': or, agouti, circ, but,
# Nearest to 'it': he, this, there, which,
# Nearest to 'there': it, which, albany, he,
# Nearest to 'eight': six, nine, seven, five,
# Nearest to 'or': and, circ, dasyprocta, UNK,
# Nearest to 'other': different, three, several, shirkuh,
# Nearest to 'be': have, been, by, was,
# Nearest to 'years': dasyprocta, eurovision, five, three,
# Nearest to 'up': dasyprocta, decorate, amalthea, storms,
# Nearest to 'these': many, two, all, cordoba,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, the, his, abakan,
# Nearest to 'five': four, six, three, seven,
# Nearest to 'united': agouti, agave, troops, accounting,
# Nearest to 'between': from, in, traditional, beadwork,
#
# Average loss at step  48000 :  5.241635418176651
# Nearest to 'people': kapoor, xxvii, plantation, amalthea,
# Nearest to 'and': or, agouti, but, circ,
# Nearest to 'it': he, this, which, there,
# Nearest to 'there': it, which, he, albany,
# Nearest to 'eight': nine, six, seven, four,
# Nearest to 'or': and, circ, kapoor, dasyprocta,
# Nearest to 'other': different, several, three, shirkuh,
# Nearest to 'be': have, been, was, is,
# Nearest to 'years': dasyprocta, eurovision, five, three,
# Nearest to 'up': decorate, dasyprocta, amalthea, storms,
# Nearest to 'these': many, all, cordoba, two,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, the, his, coke,
# Nearest to 'five': four, six, three, seven,
# Nearest to 'united': agouti, agave, troops, accounting,
# Nearest to 'between': in, from, traditional, beadwork,
#
# Average loss at step  50000 :  4.9839777117967605
# Nearest to 'people': kapoor, amalthea, xxvii, badges,
# Nearest to 'and': or, agouti, but, circ,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, which, he, they,
# Nearest to 'eight': six, seven, nine, four,
# Nearest to 'or': and, three, circ, dasyprocta,
# Nearest to 'other': different, three, several, shirkuh,
# Nearest to 'be': have, was, is, been,
# Nearest to 'years': dasyprocta, eurovision, five, three,
# Nearest to 'up': decorate, dasyprocta, on, amalthea,
# Nearest to 'these': many, two, all, cordoba,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': six, four, three, seven,
# Nearest to 'united': agouti, agave, accounting, troops,
# Nearest to 'between': in, from, traditional, beadwork,
#
# Average loss at step  52000 :  5.055599905848503
# Nearest to 'people': kapoor, ursus, amalthea, dasyprocta,
# Nearest to 'and': or, agouti, ursus, dasyprocta,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, which, he, they,
# Nearest to 'eight': six, seven, nine, five,
# Nearest to 'or': and, ursus, circ, kapoor,
# Nearest to 'other': different, three, several, shirkuh,
# Nearest to 'be': have, was, is, been,
# Nearest to 'years': dasyprocta, eurovision, five, days,
# Nearest to 'up': decorate, on, dasyprocta, amalthea,
# Nearest to 'these': many, two, cordoba, all,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, the, his, abakan,
# Nearest to 'five': four, six, three, seven,
# Nearest to 'united': agouti, agave, accounting, troops,
# Nearest to 'between': in, from, traditional, beadwork,
#
# Average loss at step  54000 :  5.181677251458168
# Nearest to 'people': kapoor, ursus, xxvii, badges,
# Nearest to 'and': or, but, ursus, agouti,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, which, they, he,
# Nearest to 'eight': six, nine, five, four,
# Nearest to 'or': and, ursus, kapoor, dasyprocta,
# Nearest to 'other': different, three, several, shirkuh,
# Nearest to 'be': have, was, been, by,
# Nearest to 'years': dasyprocta, eurovision, five, days,
# Nearest to 'up': decorate, dasyprocta, on, them,
# Nearest to 'these': many, two, some, all,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': six, four, three, eight,
# Nearest to 'united': agouti, agave, accounting, troops,
# Nearest to 'between': from, in, traditional, beadwork,
#
# Average loss at step  56000 :  5.0622010576725005
# Nearest to 'people': kapoor, ursus, amalthea, xxvii,
# Nearest to 'and': or, agouti, but, dasyprocta,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, which,
# Nearest to 'eight': six, nine, seven, four,
# Nearest to 'or': and, ursus, dasyprocta, kapoor,
# Nearest to 'other': different, several, three, shirkuh,
# Nearest to 'be': have, been, was, by,
# Nearest to 'years': dasyprocta, eurovision, five, days,
# Nearest to 'up': decorate, on, dasyprocta, them,
# Nearest to 'these': many, two, some, all,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': four, six, three, eight,
# Nearest to 'united': agouti, agave, accounting, troops,
# Nearest to 'between': in, from, traditional, with,
#
# Average loss at step  58000 :  5.037133178114891
# Nearest to 'people': kapoor, ursus, xxvii, amalthea,
# Nearest to 'and': or, agouti, circ, dasyprocta,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, he, they, which,
# Nearest to 'eight': six, nine, seven, four,
# Nearest to 'or': and, ursus, dasyprocta, kapoor,
# Nearest to 'other': different, several, three, bayonne,
# Nearest to 'be': have, been, was, by,
# Nearest to 'years': dasyprocta, eurovision, days, five,
# Nearest to 'up': decorate, them, out, dasyprocta,
# Nearest to 'these': many, two, some, all,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': four, six, three, eight,
# Nearest to 'united': agouti, agave, accounting, troops,
# Nearest to 'between': in, from, traditional, with,
#
# Average loss at step  60000 :  4.945212220072746
# Nearest to 'people': kapoor, pulau, ursus, zero,
# Nearest to 'and': or, agouti, circ, dasyprocta,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, he, they, which,
# Nearest to 'eight': nine, six, seven, four,
# Nearest to 'or': and, ursus, kapoor, dasyprocta,
# Nearest to 'other': different, three, several, bayonne,
# Nearest to 'be': have, been, was, sanjaks,
# Nearest to 'years': dasyprocta, five, days, eurovision,
# Nearest to 'up': them, decorate, out, dasyprocta,
# Nearest to 'these': many, two, some, all,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': six, four, eight, three,
# Nearest to 'united': agouti, agave, accounting, troops,
# Nearest to 'between': in, from, traditional, with,
#
# Average loss at step  62000 :  5.011711706399917
# Nearest to 'people': kapoor, pulau, ursus, xxvii,
# Nearest to 'and': or, but, agouti, dasyprocta,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, he, they, which,
# Nearest to 'eight': nine, six, seven, four,
# Nearest to 'or': and, ursus, dasyprocta, circ,
# Nearest to 'other': different, several, three, many,
# Nearest to 'be': have, been, was, by,
# Nearest to 'years': dasyprocta, days, five, eurovision,
# Nearest to 'up': them, out, dasyprocta, decorate,
# Nearest to 'these': many, some, all, two,
# Nearest to 'has': had, was, is, have,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': four, six, eight, three,
# Nearest to 'united': agouti, agave, accounting, thibetanus,
# Nearest to 'between': from, in, traditional, with,
#
# Average loss at step  64000 :  4.845853307783604
# Nearest to 'people': cardiomyopathy, kapoor, ursus, pulau,
# Nearest to 'and': or, ursus, agouti, dasyprocta,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, which,
# Nearest to 'eight': six, nine, seven, four,
# Nearest to 'or': and, ursus, dasyprocta, circ,
# Nearest to 'other': different, several, three, bayonne,
# Nearest to 'be': have, been, was, by,
# Nearest to 'years': dasyprocta, days, four, eurovision,
# Nearest to 'up': them, out, decorate, dasyprocta,
# Nearest to 'these': many, some, all, cordoba,
# Nearest to 'has': had, was, have, is,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': six, four, three, eight,
# Nearest to 'united': agouti, agave, accounting, thibetanus,
# Nearest to 'between': in, from, with, traditional,
#
# Average loss at step  66000 :  4.587773993492126
# Nearest to 'people': cardiomyopathy, kapoor, ursus, pulau,
# Nearest to 'and': or, dasyprocta, agouti, ursus,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, which,
# Nearest to 'eight': six, seven, nine, four,
# Nearest to 'or': and, ursus, dasyprocta, circ,
# Nearest to 'other': different, three, several, dasyprocta,
# Nearest to 'be': have, been, was, sanjaks,
# Nearest to 'years': dasyprocta, days, four, six,
# Nearest to 'up': them, out, decorate, dasyprocta,
# Nearest to 'these': many, some, all, two,
# Nearest to 'has': had, was, have, is,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': six, four, three, eight,
# Nearest to 'united': agouti, agave, accounting, thibetanus,
# Nearest to 'between': with, from, in, traditional,
#
# Average loss at step  68000 :  5.001810248732567
# Nearest to 'people': cardiomyopathy, kapoor, ursus, pulau,
# Nearest to 'and': or, dasyprocta, agouti, ursus,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, still,
# Nearest to 'eight': six, seven, nine, five,
# Nearest to 'or': and, ursus, circ, dasyprocta,
# Nearest to 'other': different, several, three, many,
# Nearest to 'be': been, have, by, was,
# Nearest to 'years': days, dasyprocta, four, eurovision,
# Nearest to 'up': out, them, decorate, dasyprocta,
# Nearest to 'these': many, some, all, sugarcubes,
# Nearest to 'has': had, was, have, is,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': six, four, eight, three,
# Nearest to 'united': clo, agouti, agave, accounting,
# Nearest to 'between': from, with, traditional, main,
#
# Average loss at step  70000 :  4.890041896820068
# Nearest to 'people': kapoor, cardiomyopathy, ursus, pulau,
# Nearest to 'and': or, agouti, ursus, but,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, which,
# Nearest to 'eight': six, nine, seven, five,
# Nearest to 'or': and, ursus, dasyprocta, circ,
# Nearest to 'other': different, several, many, three,
# Nearest to 'be': been, have, by, are,
# Nearest to 'years': days, dasyprocta, eurovision, five,
# Nearest to 'up': them, out, decorate, dasyprocta,
# Nearest to 'these': many, some, all, two,
# Nearest to 'has': had, was, have, is,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': four, six, eight, three,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': from, with, traditional, main,
#
# Average loss at step  72000 :  4.753865320086479
# Nearest to 'people': kapoor, cardiomyopathy, ursus, pulau,
# Nearest to 'and': or, dasyprocta, agouti, ursus,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, which,
# Nearest to 'eight': six, nine, seven, five,
# Nearest to 'or': and, ursus, dasyprocta, circ,
# Nearest to 'other': different, several, many, three,
# Nearest to 'be': been, have, by, is,
# Nearest to 'years': days, dasyprocta, eurovision, five,
# Nearest to 'up': them, out, dasyprocta, decorate,
# Nearest to 'these': many, some, all, two,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': six, four, seven, eight,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': from, with, in, traditional,
#
# Average loss at step  74000 :  4.8145572782754895
# Nearest to 'people': kapoor, cardiomyopathy, ursus, pulau,
# Nearest to 'and': or, agouti, but, ursus,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, which,
# Nearest to 'eight': six, nine, seven, four,
# Nearest to 'or': and, ursus, dasyprocta, circ,
# Nearest to 'other': different, several, bayonne, three,
# Nearest to 'be': been, have, by, is,
# Nearest to 'years': days, dasyprocta, eurovision, four,
# Nearest to 'up': them, out, decorate, off,
# Nearest to 'these': many, some, all, such,
# Nearest to 'has': had, was, have, is,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': four, six, three, seven,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': from, with, in, traditional,
#
# Average loss at step  76000 :  4.714135579228401
# Nearest to 'people': kapoor, cardiomyopathy, ursus, pulau,
# Nearest to 'and': or, but, in, agouti,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, still,
# Nearest to 'eight': nine, six, seven, five,
# Nearest to 'or': and, ursus, dasyprocta, circ,
# Nearest to 'other': different, several, many, various,
# Nearest to 'be': been, have, was, by,
# Nearest to 'years': days, dasyprocta, eurovision, guests,
# Nearest to 'up': out, them, dasyprocta, off,
# Nearest to 'these': many, some, all, are,
# Nearest to 'has': had, was, have, is,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': four, six, seven, three,
# Nearest to 'united': unassigned, clo, agouti, accounting,
# Nearest to 'between': from, with, in, traditional,
#
# Average loss at step  78000 :  4.808535810768604
# Nearest to 'people': kapoor, cardiomyopathy, ursus, pulau,
# Nearest to 'and': or, agouti, dasyprocta, but,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, still,
# Nearest to 'eight': nine, six, seven, five,
# Nearest to 'or': and, ursus, dasyprocta, kapoor,
# Nearest to 'other': different, several, various, many,
# Nearest to 'be': been, have, was, by,
# Nearest to 'years': days, dasyprocta, eurovision, guests,
# Nearest to 'up': out, them, off, dasyprocta,
# Nearest to 'these': many, some, all, such,
# Nearest to 'has': had, was, have, is,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': six, four, seven, eight,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': from, in, with, traditional,
#
# Average loss at step  80000 :  4.808480064868927
# Nearest to 'people': kapoor, cardiomyopathy, pulau, ursus,
# Nearest to 'and': or, agouti, ursus, circ,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, which,
# Nearest to 'eight': nine, seven, six, five,
# Nearest to 'or': and, ursus, nuke, thaler,
# Nearest to 'other': different, several, various, many,
# Nearest to 'be': have, been, was, by,
# Nearest to 'years': days, dasyprocta, eurovision, guests,
# Nearest to 'up': them, out, off, decorate,
# Nearest to 'these': many, some, all, such,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': four, six, seven, eight,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': from, in, with, traditional,
#
# Average loss at step  82000 :  4.778648620843887
# Nearest to 'people': kapoor, cardiomyopathy, ursus, pulau,
# Nearest to 'and': or, but, agouti, circ,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, still,
# Nearest to 'eight': seven, six, nine, five,
# Nearest to 'or': and, ursus, thaler, kapoor,
# Nearest to 'other': different, several, various, many,
# Nearest to 'be': been, have, was, by,
# Nearest to 'years': days, dasyprocta, eurovision, guests,
# Nearest to 'up': out, them, off, decorate,
# Nearest to 'these': many, some, all, two,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, circ,
# Nearest to 'five': six, four, seven, three,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': from, with, in, traditional,
#
# Average loss at step  84000 :  4.747899239301682
# Nearest to 'people': kapoor, cardiomyopathy, ursus, pulau,
# Nearest to 'and': or, agouti, but, dinar,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, still,
# Nearest to 'eight': seven, six, nine, five,
# Nearest to 'or': and, ursus, thaler, kapoor,
# Nearest to 'other': different, several, various, many,
# Nearest to 'be': been, have, was, by,
# Nearest to 'years': days, dasyprocta, eurovision, guests,
# Nearest to 'up': out, them, off, decorate,
# Nearest to 'these': many, some, all, such,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': six, four, seven, eight,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': from, with, in, traditional,
#
# Average loss at step  86000 :  4.779239269614219
# Nearest to 'people': kapoor, cardiomyopathy, ursus, pulau,
# Nearest to 'and': or, but, agouti, dasyprocta,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, still,
# Nearest to 'eight': seven, nine, six, five,
# Nearest to 'or': and, ursus, thaler, dasyprocta,
# Nearest to 'other': different, various, several, three,
# Nearest to 'be': been, have, was, by,
# Nearest to 'years': days, dasyprocta, guests, eurovision,
# Nearest to 'up': out, them, off, decorate,
# Nearest to 'these': many, some, all, such,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, circ,
# Nearest to 'five': four, six, seven, eight,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': from, with, in, traditional,
#
# Average loss at step  88000 :  4.746683409929275
# Nearest to 'people': kapoor, cardiomyopathy, pulau, ursus,
# Nearest to 'and': or, but, agouti, dasyprocta,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, this,
# Nearest to 'eight': seven, nine, six, five,
# Nearest to 'or': and, ursus, thaler, dasyprocta,
# Nearest to 'other': different, various, several, three,
# Nearest to 'be': been, have, was, by,
# Nearest to 'years': days, dasyprocta, guests, eurovision,
# Nearest to 'up': out, them, off, decorate,
# Nearest to 'these': many, some, all, several,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': four, six, seven, eight,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': in, from, with, through,
#
# Average loss at step  90000 :  4.9850886633396145
# Nearest to 'people': kapoor, cardiomyopathy, ursus, pulau,
# Nearest to 'and': or, but, agouti, dasyprocta,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, still,
# Nearest to 'eight': seven, nine, six, five,
# Nearest to 'or': and, ursus, thaler, kapoor,
# Nearest to 'other': different, various, several, three,
# Nearest to 'be': been, have, by, was,
# Nearest to 'years': days, dasyprocta, guests, eurovision,
# Nearest to 'up': out, them, off, decorate,
# Nearest to 'these': many, some, all, several,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, abakan,
# Nearest to 'five': four, seven, eight, six,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': with, in, from, through,
#
# Average loss at step  92000 :  4.6606374747753145
# Nearest to 'people': kapoor, ursus, pulau, cardiomyopathy,
# Nearest to 'and': or, but, agouti, circ,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, still,
# Nearest to 'eight': seven, nine, five, six,
# Nearest to 'or': and, but, ursus, thaler,
# Nearest to 'other': different, various, several, three,
# Nearest to 'be': been, have, by, was,
# Nearest to 'years': days, dasyprocta, guests, eurovision,
# Nearest to 'up': out, them, off, decorate,
# Nearest to 'these': many, some, all, several,
# Nearest to 'has': had, have, is, was,
# Nearest to 'its': their, his, the, circ,
# Nearest to 'five': seven, four, six, eight,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': with, from, in, through,
#
# Average loss at step  94000 :  4.711570058226585
# Nearest to 'people': kapoor, badges, ursus, pulau,
# Nearest to 'and': or, but, agouti, dinar,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, still,
# Nearest to 'eight': seven, five, nine, six,
# Nearest to 'or': and, ursus, but, kapoor,
# Nearest to 'other': different, various, several, many,
# Nearest to 'be': been, have, was, refer,
# Nearest to 'years': days, dasyprocta, guests, eurovision,
# Nearest to 'up': out, them, off, decorate,
# Nearest to 'these': many, some, all, several,
# Nearest to 'has': had, have, is, was,
# Nearest to 'its': their, his, the, circ,
# Nearest to 'five': four, seven, eight, six,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': with, from, through, in,
#
# Average loss at step  96000 :  4.6842551370859145
# Nearest to 'people': kapoor, ursus, badges, pulau,
# Nearest to 'and': or, but, agouti, circ,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, still,
# Nearest to 'eight': seven, nine, six, five,
# Nearest to 'or': and, ursus, kapoor, thaler,
# Nearest to 'other': different, various, several, many,
# Nearest to 'be': been, have, was, by,
# Nearest to 'years': days, dasyprocta, guests, eurovision,
# Nearest to 'up': out, off, them, decorate,
# Nearest to 'these': many, some, all, such,
# Nearest to 'has': had, have, is, was,
# Nearest to 'its': their, the, his, circ,
# Nearest to 'five': seven, four, six, eight,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': with, from, in, through,
#
# Average loss at step  98000 :  4.6020177227258685
# Nearest to 'people': kapoor, ursus, pulau, badges,
# Nearest to 'and': or, but, agouti, dasyprocta,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, still,
# Nearest to 'eight': seven, six, nine, five,
# Nearest to 'or': and, ursus, thaler, kapoor,
# Nearest to 'other': different, various, three, several,
# Nearest to 'be': been, have, was, refer,
# Nearest to 'years': days, dasyprocta, guests, five,
# Nearest to 'up': out, them, off, him,
# Nearest to 'these': many, some, all, several,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, circ,
# Nearest to 'five': four, seven, six, three,
# Nearest to 'united': unassigned, clo, agouti, agave,
# Nearest to 'between': with, from, through, in,
#
# Average loss at step  100000 :  4.686010946989059
# Nearest to 'people': kapoor, ursus, pulau, badges,
# Nearest to 'and': or, but, agouti, dasyprocta,
# Nearest to 'it': he, this, there, she,
# Nearest to 'there': it, they, he, still,
# Nearest to 'eight': seven, nine, six, five,
# Nearest to 'or': and, ursus, thaler, kapoor,
# Nearest to 'other': different, various, several, many,
# Nearest to 'be': been, have, is, was,
# Nearest to 'years': days, dasyprocta, guests, five,
# Nearest to 'up': out, off, them, him,
# Nearest to 'these': many, some, all, several,
# Nearest to 'has': had, have, was, is,
# Nearest to 'its': their, his, the, circ,
# Nearest to 'five': four, three, seven, six,
# Nearest to 'united': unassigned, clo, agouti, accounting,
# Nearest to 'between': from, with, in, through,

# %% [markdown]
# <center><img src="../images/watiing.jpg" width="700"/></center>

# %% [markdown]
# -----
# Step 6: Visualize the embeddings.
# ----
#
# We'll use t-sne.
#
# [t-sne](https://lvdmaaten.github.io/tsne/) is a cool way to visualize of high-dimensional datasets by reducing the number dimensions.

# %%
tsne = TSNE(perplexity=30, 
            n_components=2, 
            init='pca', 
            n_iter=5_000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]

n_words_to_visualize = 40

for i, label in enumerate(labels[:n_words_to_visualize]):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

# %% [markdown]
# ----
# Reflective Questions
# ----
#
# What do you see?
#
# How would you describe the relationships?

# %% [markdown]
# I see clusters of related words, such as a cluster of prepositions and conjunctions, a cluster of verbs and a cluster of pronouns.
# The words are also grouped in case of numbers (one, two, seven) and UNK shows up more isolated, as 's' and 'to'.

# %% [markdown]
# ------
#
# Let's render and save more samples.

# %%
def plot_with_labels(low_dim_embs, labels, filename='../images/tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in range(plot_only)]
plot_with_labels(low_dim_embs, labels)

# %% [markdown]
# Embedding Visualizer
# ------
# Check out a better version: [Embedding projector](https://www.tensorflow.org/tensorboard/tensorboard_projector_plugin)
